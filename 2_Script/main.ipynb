# %%
import Functions_Package as fp

# %%
file_dsm = r'C:\GitHub\LWP_Vineyard_Features\1_Data\Demo_DSM.tif'
file_rgb = r'C:\GitHub\LWP_Vineyard_Features\1_Data\Demo_RGBNIR.tif'
file_tr = r'C:\GitHub\LWP_Vineyard_Features\1_Data\Demo_Tr.tif'
file_mask = r'C:\GitHub\LWP_Vineyard_Features\1_Data\Area.shp'
file_points = r'C:\GitHub\LWP_Vineyard_Features\1_Data\Points.shp'

dir_output = r'C:\GitHub\LWP_Vineyard_Features\3_Results'
dir_table_output = r'C:\GitHub\LWP_Vineyard_Features\3_Results'
fp.FolderCreater(dir_output)

[file_number,
 resolution_high,resolution_low,
 threshold_ndvi,l_SAVI,
 NoDataValue] = ['20150602_1041',
                 0.15,0.60,
                 0.65,0.5,
                 -9999]

# %%
fp.Features_To_Points(file_dsm,file_rgb,file_tr,file_mask,file_points,
                      dir_output,
                      dir_table_output,
                      file_number,resolution_high,resolution_low,
                      threshold_ndvi,
                      l_SAVI,
                      NoDataValue)
print("\n\nPROCESSING FINISHED!!!")
# Out:
# The horizontal resolution is 0.15m and the vertical resolution is 0.15m.
# The horizontal resolution is 0.15m and the vertical resolution is 0.15m.
# The horizontal resolution is 0.6m and the vertical resolution is 0.6m.
# Dimension of the data is: 1560 3216
# The extent is: 664135.5726914577 4239771.465933865 664617.9726914577 4240005.465933865
# Done!!! Tiff data has been written: C:\GitHub\LWP_Vineyard_Features\3_Results\cls_20150602_1041_NDVI.tif
# Done!!! Tiff data has been written: C:\GitHub\LWP_Vineyard_Features\3_Results\tmp_vi_20150602_1041_NDVI.tif
# Done!!! Tiff data has been written: C:\GitHub\LWP_Vineyard_Features\3_Results\tmp_vi_20150602_1041_cig.tif
# Done!!! Tiff data has been written: C:\GitHub\LWP_Vineyard_Features\3_Results\tmp_vi_20150602_1041_MSAVI.tif
# Done!!! Tiff data has been written: C:\GitHub\LWP_Vineyard_Features\3_Results\tmp_vi_20150602_1041_MTVI2.tif
# ...
